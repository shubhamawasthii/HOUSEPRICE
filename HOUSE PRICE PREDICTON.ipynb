# %% [markdown]
#    ### HOUSE PRICE PREDICTION

# %% [markdown]
# SHUBHAM AWASTHI

# %%
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
house=pd.read_csv(r"C:\Users\PC CARE\Downloads\kc_house_train_data - kc_house_train_data.csv")
house
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 0     2487200875  20141209T000000   604000.0         4       3.00
# 1     7237550310  20140512T000000  1230000.0         4       4.50
# 2     9212900260  20140527T000000   468000.0         2       1.00
# 3      114101516  20140528T000000   310000.0         3       1.00
# 4     6054650070  20141007T000000   400000.0         3       1.75
# ...          ...              ...        ...       ...        ...
# 9756  9834201367  20150126T000000   429000.0         3       2.00
# 9757  3448900210  20141014T000000   610685.0         4       2.50
# 9758  7936000429  20150326T000000  1010000.0         4       3.50
# 9759  1523300141  20140623T000000   402101.0         2       0.75
# 9760  1523300157  20141015T000000   325000.0         2       0.75
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 0            1960      5000     1.0           0     0  ...      7        1050
# 1            5420    101930     1.0           0     0  ...     11        3890
# 2            1160      6000     1.0           0     0  ...      7         860
# 3            1430     19901     1.5           0     0  ...      7        1430
# 4            1370      9680     1.0           0     0  ...      7        1370
# ...           ...       ...     ...         ...   ...  ...    ...         ...
# 9756         1490      1126     3.0           0     0  ...      8        1490
# 9757         2520      6023     2.0           0     0  ...      9        2520
# 9758         3510      7200     2.0           0     0  ...      9        2600
# 9759         1020      1350     2.0           0     0  ...      7        1020
# 9760         1020      1076     2.0           0     0  ...      7        1020
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0               910      1965             0    98136  47.5208 -122.393
# 1              1530      2001             0    98053  47.6561 -122.005
# 2               300      1942             0    98115  47.6900 -122.292
# 3                 0      1927             0    98028  47.7558 -122.229
# 4                 0      1977             0    98074  47.6127 -122.045
# ...             ...       ...           ...      ...      ...      ...
# 9756              0      2014             0    98144  47.5699 -122.288
# 9757              0      2014             0    98056  47.5137 -122.167
# 9758            910      2009             0    98136  47.5537 -122.398
# 9759              0      2009             0    98144  47.5944 -122.299
# 9760              0      2008             0    98144  47.5941 -122.299
#
#       sqft_living15  sqft_lot15
# 0              1360        5000
# 1              4760      101930
# 2              1330        6000
# 3              1780       12697
# 4              1370       10208
# ...             ...         ...
# 9756           1400        1230
# 9757           2520        6023
# 9758           2050        6200
# 9759           1020        2007
# 9760           1020        1357
#
# [9761 rows x 21 columns]

# %%
house.drop(["sqft_living15", "sqft_lot15"], axis = 1, inplace = True)
house
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 0     2487200875  20141209T000000   604000.0         4       3.00
# 1     7237550310  20140512T000000  1230000.0         4       4.50
# 2     9212900260  20140527T000000   468000.0         2       1.00
# 3      114101516  20140528T000000   310000.0         3       1.00
# 4     6054650070  20141007T000000   400000.0         3       1.75
# ...          ...              ...        ...       ...        ...
# 9756  9834201367  20150126T000000   429000.0         3       2.00
# 9757  3448900210  20141014T000000   610685.0         4       2.50
# 9758  7936000429  20150326T000000  1010000.0         4       3.50
# 9759  1523300141  20140623T000000   402101.0         2       0.75
# 9760  1523300157  20141015T000000   325000.0         2       0.75
#
#       sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 0            1960      5000     1.0           0     0          5      7
# 1            5420    101930     1.0           0     0          3     11
# 2            1160      6000     1.0           0     0          4      7
# 3            1430     19901     1.5           0     0          4      7
# 4            1370      9680     1.0           0     0          4      7
# ...           ...       ...     ...         ...   ...        ...    ...
# 9756         1490      1126     3.0           0     0          3      8
# 9757         2520      6023     2.0           0     0          3      9
# 9758         3510      7200     2.0           0     0          3      9
# 9759         1020      1350     2.0           0     0          3      7
# 9760         1020      1076     2.0           0     0          3      7
#
#       sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0           1050            910      1965             0    98136  47.5208
# 1           3890           1530      2001             0    98053  47.6561
# 2            860            300      1942             0    98115  47.6900
# 3           1430              0      1927             0    98028  47.7558
# 4           1370              0      1977             0    98074  47.6127
# ...          ...            ...       ...           ...      ...      ...
# 9756        1490              0      2014             0    98144  47.5699
# 9757        2520              0      2014             0    98056  47.5137
# 9758        2600            910      2009             0    98136  47.5537
# 9759        1020              0      2009             0    98144  47.5944
# 9760        1020              0      2008             0    98144  47.5941
#
#          long
# 0    -122.393
# 1    -122.005
# 2    -122.292
# 3    -122.229
# 4    -122.045
# ...       ...
# 9756 -122.288
# 9757 -122.167
# 9758 -122.398
# 9759 -122.299
# 9760 -122.299
#
# [9761 rows x 19 columns]

# %% [markdown]
# Questions we would try to answer using this dat set are

# %% [markdown]
# 1 : How is price of house related to living area. According to our assumption these are directly proportional to each other

# %% [markdown]
# 2: How does lot area affects the price of the house

# %% [markdown]
# 3 : Does having a water front affects the price of house .

# %% [markdown]
# 4 : We are assuming that having more bedrooms, more bathrooms increase the price of the house

# %% [markdown]
# 5 : Are houses from a particular locality or a particular location being priced higher than other houses

# %% [markdown]
# ### Analyzing the data using UNIVARIATE ANALYSIS

# %%
house['floors'].value_counts()
# Out:
# 1.0    4862
# 2.0    3723
# 1.5     867
# 3.0     245
# 2.5      62
# 3.5       2
# Name: floors, dtype: int64

# %%
house['waterfront'].value_counts()
# Out:
# 0    9679
# 1      82
# Name: waterfront, dtype: int64

# %%
house['view'].value_counts()
# Out:
# 0    8748
# 2     454
# 3     243
# 1     160
# 4     156
# Name: view, dtype: int64

# %%
house['grade'].value_counts()
# Out:
# 7     4067
# 8     2707
# 9     1192
# 6      914
# 10     532
# 11     172
# 5      107
# 12      45
# 4       17
# 13       7
# 1        1
# Name: grade, dtype: int64

# %%
house['condition'].value_counts()
# Out:
# 3    6291
# 4    2610
# 5     772
# 2      78
# 1      10
# Name: condition, dtype: int64

# %%
house['bedrooms'].value_counts()
# Out:
# 3     4417
# 4     3094
# 2     1255
# 5      755
# 6      116
# 1       88
# 7       17
# 8        7
# 0        6
# 9        3
# 11       1
# 10       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
house['zipcode'].value_counts()
# Out:
# 98115    278
# 98052    264
# 98034    257
# 98103    257
# 98117    257
#         ...
# 98010     48
# 98109     44
# 98024     37
# 98148     26
# 98039     20
# Name: zipcode, Length: 70, dtype: int64

# %%
sns.distplot(house.yr_built)
# Out:
# C:\Users\PC CARE\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='yr_built', ylabel='Density'>

# %%
sns.distplot(house.sqft_lot)
# Out:
# C:\Users\PC CARE\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sqft_lot', ylabel='Density'>

# %%
sns.distplot(house.sqft_living)
# Out:
# C:\Users\PC CARE\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sqft_living', ylabel='Density'>

# %%
sns.displot(house.sqft_above)

# %%
sns.displot(house.sqft_basement)

# %% [markdown]
# ## BIVARIATE ANALYSIS

# %% [markdown]
# ### Plot between Living area and price

# %%
house.plot(kind='scatter',         # type of plot to be plotted
         x='sqft_living',y='price',      # the variable in xand y
         color='orange',
         figsize=(10,10))
plt.xlabel("living area",fontsize=16)
plt.ylabel("price",fontsize=16)
plt.title("scatter plot",fontsize=16)
plt.show()

# %% [markdown]
# ### Plot between Lot area and Price

# %%
house.plot(kind='scatter',         # type of plot to be plotted
         x='sqft_lot',y='price',      # the variable in xand y
         color='magenta',
         figsize=(10,10))
plt.xlabel("sqft_lot",fontsize=16)
plt.ylabel("price",fontsize=16)
plt.xlim( [ 500, 25000 ] ) 
plt.title("scatter plot",fontsize=16)
plt.show()

# %% [markdown]
# ### Scatter Plot between squarefoot above and price

# %%
house.plot(kind='scatter',         # type of plot to be plotted
         x='sqft_above',y='price',      # the variable in xand y
         color='orange',
         figsize=(10,10))
plt.xlabel("sqft_above",fontsize=12)
plt.ylabel("price",fontsize=12)
plt.title("scatter plot",fontsize=14)
plt.show()

# %% [markdown]
# ### Scatter plot between bathrooms and price

# %%
house.plot(kind='scatter',         # type of plot to be plotted
         x='bathrooms',y='price',      # the variable in xand y
         color='orange',
         figsize=(10,10))
plt.xlabel("bathrooms",fontsize=12)
plt.ylabel("price",fontsize=12)
plt.title("scatter plot",fontsize=14)
plt.show()

# %% [markdown]
# ### Affect of having waterfront on price

# %%
bplot=house.boxplot(column="price",
             notch=True,
             by="waterfront",patch_artist=True,
             grid=True,
             figsize=(10,10))
                              # to plot vertical boxplot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### How prices vary according to zip code

# %%
bplot=house.boxplot(column="price",
             notch=True,
             by="zipcode",patch_artist=True,
             grid=True,
             figsize=(10,10))
                              # to plot vertical boxplot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### How prices vary according to zip code``

# %%
bplot=house.boxplot(column="price",
             notch=True,
             by="zipcode",patch_artist=True,
             grid=True,
             figsize=(12,12))
                              # to plot vertical boxplot
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Scatter plot between lat long showing price using gradient colouring

# %%
plt.subplots(figsize=(16,16))
plt.scatter(house.lat, house.long, s=10, c=house.price, cmap='tab10')

# %% [markdown]
# ### Conclusion

# %% [markdown]
# *We see that sqft_living,living_area,sqft_above,bathrooms look directly proportional to the price of the house.
#
# *And also from the boxplot we can see that houses having waterfront are having higher average price than house with waterfront.
#
# *From the scater plot between lat and longitude the prices are shown according to gradient colour coding so it looks like house
# of similar price are together located.Also some zipcodes are having higher average prices than other which are clearly visible

# %% [markdown]
# ## Initial Model Fitting

# %%
From our Exploratory Data Analysis we can see that som factors are affecting price of hous very much ie they are directly 
to the price of the house whereas some foctors are having very little or no effect on price of house. So based on that we
are going to take 3 set of predictors 
1: grade,lat,long,zipcode,waterfront,view,age_of_house
2:all_columns-(date,id,price)
3:bedrooms,bathrooms,sqft_living,sqft_above,sqft_basemen,sqft_lot,`floors

# %% [markdown]
# ### FIRST MODEL

# %%
X = house.drop(["price","date","id"], axis=1)

y = house.price

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score

# %%
(X_train,X_test,y_train,y_test)=train_test_split(X,y,test_size=0.3)

# %%
X_scaled = X.apply(lambda x: (x - np.mean(x)) / np.std(x))

# %%
reg_tree = DecisionTreeRegressor(max_depth=12, min_samples_leaf=5) 
reg_tree.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=12, min_samples_leaf=5)

# %%
y_pred = reg_tree.predict(X_test)
y_pred
# Out:
# array([700388.47368421, 464300.        , 321388.88888889, ...,
#        528509.63768116, 484660.71428571, 212353.94594595])

# %%
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
np.mean(cross_val_score(dt, X, y, cv = 10))
# Out:
# 0.7329634483474299

# %%
# MAPE
np.mean(np.abs(y_test - y_pred)/y_test)*100
# Out:
# 17.21963857630515

# %% [markdown]
# ### SECOND MODEL

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score

# %%
X=house[[  'grade','lat','long','zipcode','waterfront','view']]
y=house.price

# %%
(X_train,X_test,y_train,y_test)=train_test_split(X,y,test_size=0.3)

# %%
X_scaled = X.apply(lambda x: (x - np.mean(x)) / np.std(x))

# %%
reg_tree = DecisionTreeRegressor(max_depth=12, min_samples_leaf=5) 
reg_tree.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=12, min_samples_leaf=5)

# %%
Yy_pred = reg_tree.predict(X_test)
y_pred
# Out:
# array([840763.33333333, 492154.64285714, 511226.6       , ...,
#        300399.5       , 272246.15384615, 501845.        ])

# %%
dt = DecisionTreeRegressor()
np.mean(cross_val_score(dt, X, y, cv = 10))
# Out:
# 0.6792458331609066

# %%
# MAPE
np.mean(np.abs(y_test - y_pred)/y_test)*100
# Out:
# 71.09629215749791

# %% [markdown]
# ### THIRD MODEL

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score

# %%
X=house[[ 'bedrooms','bathrooms',"sqft_living" ,"grade","lat","waterfront",'sqft_above']]
y=house.price

# %%
(X_train,X_test,y_train,y_test)=train_test_split(X,y,test_size=0.3)

# %%
X_scaled = X.apply(lambda x: (x - np.mean(x)) / np.std(x))

# %%
reg_tree = DecisionTreeRegressor(max_depth=20, min_samples_leaf=10) 
reg_tree.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=20, min_samples_leaf=10)

# %%
y_pred = reg_tree.predict(X_test)
y_pred
# Out:
# array([840763.33333333, 492154.64285714, 511226.6       , ...,
#        300399.5       , 272246.15384615, 501845.        ])

# %%
dt = DecisionTreeRegressor()
np.mean(cross_val_score(dt, X, y, cv = 10))
# Out:
# 0.5862384953780235

# %%
# MAPE
np.mean(np.abs(y_test - y_pred)/y_test)*100
# Out:
# 20.231512865368977

# %% [markdown]
# ## Step 4 : FEATURE ENGINEERING

# %%
# GETTING EXACT DATE
house["date"]= pd.to_datetime(house["date"])

# %%
house["year"] = pd.DatetimeIndex(house["date"]).year

# %%
# Calculating the age of house usinf its year build
house["age_of_house"] = house['year'] - house['yr_built']

# %%
# creating a new column
house['sqft_living**2']=house['sqft_living']**2

# %%
house['basement']=house['sqft_basement'].apply(lambda x:1 if x>0 else 0)
house['renovated']=house['yr_renovated'].apply(lambda x:1 if x>0 else 0)
house
# Out:
#               id       date      price  bedrooms  bathrooms  sqft_living  \
# 0     2487200875 2014-12-09   604000.0         4       3.00         1960
# 1     7237550310 2014-05-12  1230000.0         4       4.50         5420
# 2     9212900260 2014-05-27   468000.0         2       1.00         1160
# 3      114101516 2014-05-28   310000.0         3       1.00         1430
# 4     6054650070 2014-10-07   400000.0         3       1.75         1370
# ...          ...        ...        ...       ...        ...          ...
# 9756  9834201367 2015-01-26   429000.0         3       2.00         1490
# 9757  3448900210 2014-10-14   610685.0         4       2.50         2520
# 9758  7936000429 2015-03-26  1010000.0         4       3.50         3510
# 9759  1523300141 2014-06-23   402101.0         2       0.75         1020
# 9760  1523300157 2014-10-15   325000.0         2       0.75         1020
#
#       sqft_lot  floors  waterfront  view  ...  yr_built  yr_renovated  \
# 0         5000     1.0           0     0  ...      1965             0
# 1       101930     1.0           0     0  ...      2001             0
# 2         6000     1.0           0     0  ...      1942             0
# 3        19901     1.5           0     0  ...      1927             0
# 4         9680     1.0           0     0  ...      1977             0
# ...        ...     ...         ...   ...  ...       ...           ...
# 9756      1126     3.0           0     0  ...      2014             0
# 9757      6023     2.0           0     0  ...      2014             0
# 9758      7200     2.0           0     0  ...      2009             0
# 9759      1350     2.0           0     0  ...      2009             0
# 9760      1076     2.0           0     0  ...      2008             0
#
#       zipcode      lat     long  year  age_of_house  sqft_living**2  basement  \
# 0       98136  47.5208 -122.393  2014            49         3841600         1
# 1       98053  47.6561 -122.005  2014            13        29376400         1
# 2       98115  47.6900 -122.292  2014            72         1345600         1
# 3       98028  47.7558 -122.229  2014            87         2044900         0
# 4       98074  47.6127 -122.045  2014            37         1876900         0
# ...       ...      ...      ...   ...           ...             ...       ...
# 9756    98144  47.5699 -122.288  2015             1         2220100         0
# 9757    98056  47.5137 -122.167  2014             0         6350400         0
# 9758    98136  47.5537 -122.398  2015             6        12320100         1
# 9759    98144  47.5944 -122.299  2014             5         1040400         0
# 9760    98144  47.5941 -122.299  2014             6         1040400         0
#
#       renovated
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 9756          0
# 9757          0
# 9758          0
# 9759          0
# 9760          0
#
# [9761 rows x 24 columns]

# %%
plt.subplots(figsize=(8,8))
plt.scatter(house.age_of_house, house.price, s=50, c=house.renovated, cmap='rainbow')

# %% [markdown]
# ## Step 5: MODEL FITTING STEP 2

# %%
X =house.drop(['price','id','date'],axis=1)
y =house.price

# %% [markdown]
# ### Train-Test-Validation split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
#Train-Validation Split
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size = 0.25)

# %% [markdown]
# ### Fitting a Regression Tree

# %%
reg_tree = DecisionTreeRegressor(max_depth=15, min_samples_leaf=5) 
reg_tree.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=15, min_samples_leaf=5)

# %%
fig, axes = plt.subplots(figsize=(3,3), dpi=300)

tree.plot_tree(reg_tree, feature_names=list(X), filled = False)

plt.show()

# %% [markdown]
# ### Predicting

# %%
y_pred = reg_tree.predict(X_valid)
y_pred
# Out:
# array([ 796580.        ,  293096.42857143, 1361250.        , ...,
#         486400.        ,  248350.        ,  263589.72      ])

# %% [markdown]
# ### Choosing the best depth

# %%
depth = np.arange(1,15)
mae = []

for k in depth:
    reg_tree = DecisionTreeRegressor(max_depth=k, min_samples_leaf=5)
    reg_tree.fit(X_train, y_train)
    y_pred = reg_tree.predict(X_valid)
    mae.append(np.mean(np.abs(y_valid - y_pred)))

# %%
plt.plot(depth, np.array(mae))
plt.show()

# %% [markdown]
# As we can see that even if we take depth as 10 we would get almost similar accuracy as if we were to increase the depth

# %% [markdown]
# ## Step 6 : Model Testing

# %%
house_test=pd.read_csv(r"C:\Users\PC CARE\Downloads\kc_house_test_data - kc_house_test_data.csv")
house_test
# Out:
#               id             date     price  bedrooms  bathrooms  sqft_living  \
# 0     3793500160  20150312T000000  323000.0         3       2.50         1890
# 1     1175000570  20150312T000000  530000.0         5       2.00         1810
# 2       16000397  20141205T000000  189000.0         2       1.00         1200
# 3      461000390  20140624T000000  687500.0         4       1.75         2330
# 4     7895500070  20150213T000000  240000.0         4       1.00         1220
# ...          ...              ...       ...       ...        ...          ...
# 2212  6669080120  20141215T000000  405000.0         4       2.50         1980
# 2213  2855000110  20140808T000000  388000.0         3       2.50         2198
# 2214  3345700207  20150502T000000  608500.0         4       3.50         2850
# 2215  6056111067  20140707T000000  230000.0         3       1.75         1140
# 2216  2767600688  20141113T000000  414500.0         2       1.50         1210
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 0         6560     2.0           0     0  ...      7        1890
# 1         4850     1.5           0     0  ...      7        1810
# 2         9850     1.0           0     0  ...      7        1200
# 3         5000     1.5           0     0  ...      7        1510
# 4         8075     1.0           0     0  ...      7         890
# ...        ...     ...         ...   ...  ...    ...         ...
# 2212      5020     2.0           0     0  ...      7        1980
# 2213      6222     2.0           0     2  ...      8        2198
# 2214      5577     2.0           0     0  ...      8        1950
# 2215      1201     2.0           0     0  ...      8        1140
# 2216      1278     2.0           0     0  ...      8        1020
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0                 0      2003             0    98038  47.3684 -122.031
# 1                 0      1900             0    98107  47.6700 -122.394
# 2                 0      1921             0    98002  47.3089 -122.210
# 3               820      1929             0    98117  47.6823 -122.368
# 4               330      1969             0    98001  47.3341 -122.282
# ...             ...       ...           ...      ...      ...      ...
# 2212              0      2007             0    98056  47.5147 -122.190
# 2213              0      2010             0    98198  47.3906 -122.304
# 2214            900      2014             0    98056  47.5252 -122.192
# 2215              0      2014             0    98108  47.5637 -122.295
# 2216            190      2007             0    98117  47.6756 -122.375
#
#       sqft_living15  sqft_lot15
# 0              2390        7570
# 1              1360        4850
# 2              1060        5095
# 3              1460        5000
# 4              1290        7800
# ...             ...         ...
# 2212           1980        5064
# 2213           2198        7621
# 2214           2850        5708
# 2215           1210        1552
# 2216           1210        1118
#
# [2217 rows x 21 columns]

# %%
# now we are going to perform all the steps on the test data that we performed on training data

house_test.drop(["sqft_living15", "sqft_lot15"], axis = 1, inplace = True)

house_test["date"]= pd.to_datetime(house_test["date"])
house_test["year"] = pd.DatetimeIndex(house_test["date"]).year

house_test["age_of_house"] = house_test['year'] - house_test['yr_built']

house_test['sqft_living**2']=house_test['sqft_living']**2

house_test['basement']=house_test['sqft_basement'].apply(lambda x:1 if x>0 else 0)

house_test['renovated']=house_test['yr_renovated'].apply(lambda x:1 if x>0 else 0)
house_test
# Out:
#               id       date     price  bedrooms  bathrooms  sqft_living  \
# 0     3793500160 2015-03-12  323000.0         3       2.50         1890
# 1     1175000570 2015-03-12  530000.0         5       2.00         1810
# 2       16000397 2014-12-05  189000.0         2       1.00         1200
# 3      461000390 2014-06-24  687500.0         4       1.75         2330
# 4     7895500070 2015-02-13  240000.0         4       1.00         1220
# ...          ...        ...       ...       ...        ...          ...
# 2212  6669080120 2014-12-15  405000.0         4       2.50         1980
# 2213  2855000110 2014-08-08  388000.0         3       2.50         2198
# 2214  3345700207 2015-05-02  608500.0         4       3.50         2850
# 2215  6056111067 2014-07-07  230000.0         3       1.75         1140
# 2216  2767600688 2014-11-13  414500.0         2       1.50         1210
#
#       sqft_lot  floors  waterfront  view  ...  yr_built  yr_renovated  \
# 0         6560     2.0           0     0  ...      2003             0
# 1         4850     1.5           0     0  ...      1900             0
# 2         9850     1.0           0     0  ...      1921             0
# 3         5000     1.5           0     0  ...      1929             0
# 4         8075     1.0           0     0  ...      1969             0
# ...        ...     ...         ...   ...  ...       ...           ...
# 2212      5020     2.0           0     0  ...      2007             0
# 2213      6222     2.0           0     2  ...      2010             0
# 2214      5577     2.0           0     0  ...      2014             0
# 2215      1201     2.0           0     0  ...      2014             0
# 2216      1278     2.0           0     0  ...      2007             0
#
#       zipcode      lat     long  year  age_of_house  sqft_living**2  basement  \
# 0       98038  47.3684 -122.031  2015            12         3572100         0
# 1       98107  47.6700 -122.394  2015           115         3276100         0
# 2       98002  47.3089 -122.210  2014            93         1440000         0
# 3       98117  47.6823 -122.368  2014            85         5428900         1
# 4       98001  47.3341 -122.282  2015            46         1488400         1
# ...       ...      ...      ...   ...           ...             ...       ...
# 2212    98056  47.5147 -122.190  2014             7         3920400         0
# 2213    98198  47.3906 -122.304  2014             4         4831204         0
# 2214    98056  47.5252 -122.192  2015             1         8122500         1
# 2215    98108  47.5637 -122.295  2014             0         1299600         0
# 2216    98117  47.6756 -122.375  2014             7         1464100         1
#
#       renovated
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 2212          0
# 2213          0
# 2214          0
# 2215          0
# 2216          0
#
# [2217 rows x 24 columns]

# %%
X =house_test.drop(['price','id','date'],axis=1)
y =house_test.price

# %% [markdown]
# ### Test-Train-Validation Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size = 0.25)

# %% [markdown]
# ### Fitting A Regression Tree

# %%
reg_tree = DecisionTreeRegressor(max_depth=10, min_samples_leaf=5) 
reg_tree.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=10, min_samples_leaf=5)

# %%
fig, axes = plt.subplots(figsize=(3,3), dpi=300)

tree.plot_tree(reg_tree, feature_names=list(X), filled = False)

plt.show()

# %% [markdown]
# ### Predicting

# %%
y_pred = reg_tree.predict(X_valid)
y_pred
# Out:
# array([ 636708.33333333,  916920.        ,  289418.52380952,
#         172990.        ,  279996.6       ,  475358.76086957,
#         580564.28571429,  188464.28571429,  595000.        ,
#         490380.625     , 1366000.        ,  402798.58064516,
#         685847.36842105,  643100.        ,  615800.        ,
#         703950.        ,  490380.625     ,  305183.83333333,
#         402798.58064516,  283908.33333333,  414000.        ,
#         262993.33333333,  592285.71428571, 1169369.66666667,
#         636103.85714286,  246534.375     ,  554600.        ,
#         393187.5       ,  324203.60606061,  615800.        ,
#         331562.5       ,  960833.33333333,  808241.66666667,
#         490590.        ,  678600.        ,  419833.33333333,
#         519357.90909091,  479107.14285714,  567845.        ,
#         200121.42857143,  795800.        ,  224552.83333333,
#         490380.625     ,  682413.42857143,  334160.        ,
#         532600.        ,  734168.4       ,  400833.33333333,
#         410023.75      ,  851357.14285714,  377140.        ,
#         498290.        ,  435576.8125    ,  324203.60606061,
#        1457500.        ,  239483.33333333,  411500.        ,
#         713125.45454545,  406290.        ,  221593.33333333,
#        1366000.        , 1061666.66666667,  556409.09090909,
#         376216.66666667, 1066142.85714286,  322000.        ,
#         221593.33333333,  554600.        , 1169369.66666667,
#         262993.33333333,  519743.75      ,  302696.8       ,
#         475358.76086957,  436590.        ,  734168.4       ,
#        1674285.71428571,  246534.375     ,  393187.5       ,
#         636708.33333333,  289418.52380952,  221593.33333333,
